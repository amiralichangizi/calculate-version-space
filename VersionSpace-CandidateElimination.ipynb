# %% [markdown]
# **Calculate Version Space Using candidate elimination algorithm**
#
# Amirali Changizi

# %%
from google.colab import drive

drive.mount('/content/drive')
print("-------> GoogleDrive is Mounted! <-------")
# Out:
# Mounted at /content/drive
# -------> GoogleDrive is Mounted! <-------

# %%
data_set_path = "/content/drive/MyDrive/versionspace-dataset.csv"

# %%
import numpy as np
import pandas as pd
dataset = pd.read_csv(data_set_path)
dataset.head()
# Out:
#      Sky AirTemp Humidity  Wind Water Forecast class
# 0  Rainy    Cold   Normal  Weak  Cool     Same     N
# 1  Rainy    Cold   Normal  Weak  Warm     Same     N
# 2  Sunny    Warm   Normal  Weak  Warm     Same     Y
# 3  Sunny    Warm   Normal  Weak  Warm     Same     Y
# 4  Rainy    Cold     High  Weak  Cool   Change     N

# %%
result = {'Y':1, 'N':0}

# %%
dataset['class'] = dataset['class'].map(result)
dataset.head()
# Out:
#      Sky AirTemp Humidity  Wind Water Forecast  class
# 0  Rainy    Cold   Normal  Weak  Cool     Same      0
# 1  Rainy    Cold   Normal  Weak  Warm     Same      0
# 2  Sunny    Warm   Normal  Weak  Warm     Same      1
# 3  Sunny    Warm   Normal  Weak  Warm     Same      1
# 4  Rainy    Cold     High  Weak  Cool   Change      0

# %%
X = dataset.iloc[:, 0:6].values
y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [['Rainy' 'Cold' 'Normal' 'Weak' 'Cool' 'Same']
#  ['Rainy' 'Cold' 'Normal' 'Weak' 'Warm' 'Same']
#  ['Sunny' 'Warm' 'Normal' 'Weak' 'Warm' 'Same']
#  ...
#  ['Sunny' 'Warm' 'Normal' 'Weak' 'Warm' 'Same']
#  ['Sunny' 'Warm' 'Normal' 'Weak' 'Warm' 'Change']
#  ['Rainy' 'Cold' 'Normal' 'Strong' 'Warm' 'Same']]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(X,y):
 X_train, X_test = X[train_index], X[test_index]
 y_train, y_test = y[train_index], y[test_index]

# %%
# !pip install classic-CandidateElimination
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from classic_CandidateElimination import Candidate_Elimination
ce = Candidate_Elimination()
ce.fit(X_train, y_train)
y_pred = ce.predict(X_test)
# Out:
# Initial Specific Hypothesis :  ['Rainy', 'Cold', 'Normal', 'Weak', 'Cool', 'Same']
# Initial General Hypothesis :  [['?', '?', '?', '?', '?', '?']]
# Final Specific Hypothesis :  ['?', '?', 'Normal', 'Weak', '?', '?']
# Final General Hypothesis :  [['?', '?', '?', '?', '?', '?'], ['?', '?', 'Normal', '?', '?', '?'], ['?', '?', '?', 'Weak', '?', '?']]
# Final Version Space :  [['?', '?', 'Normal', '?', '?', '?'], ['?', '?', 'Normal', 'Weak', '?', '?'], ['?', '?', 'Normal', 'Weak', '?', '?'], ['?', '?', '?', 'Weak', '?', '?']]
# 434   466
